# %% [markdown]
# # DISTRIBUIÇÃO NORMAL ou DISTRIBUIÇÃO GAUSSIANA.

# %% [markdown]
#     2.1. Gere um plot da densidade de probabilidade da distribuição e de sua cumulativa. Descubra como usando o pacote scipy.stats

# %%
# %matplotlib inline

import os
import matplotlib.pyplot as plt
import pandas as pd
import scipy
from scipy.stats import norm
import numpy as np
import math

# %%
x = np.linspace(norm.ppf(0.01),norm.ppf(0.99), 100)
plt.plot(x, norm.pdf(x),'r-', lw=5, alpha=0.6, label='norm pdf')
rv = norm()
plt.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %% [markdown]
#     Aqui temos a curva referente à distribuição normal

# %%
cdf = stats.binom.cdf
plt.plot(x,norm.cdf(x))
plt.show()

# %% [markdown]
#     Acima temos a probabilidade acumulada da distribuição normal

# %%
x = np.linspace(norm.ppf(0.01),norm.ppf(0.99), 100)
cdf = stats.binom.cdf
plt.plot(x,norm.cdf(x))
plt.plot(x, norm.pdf(x),'r-', lw=5, alpha=0.6, label='norm pdf')
rv = norm()
plt.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %% [markdown]
#     E por último temos um plot com os dois gráficos juntos, para ficar mais fácil de observar a relação entre eles.

# %% [markdown]
#
#
#
#     2.2. Qual a forma analítica (expressão) da distribuição?

# %% [markdown]
# <img src="expana.png">

# %% [markdown]
#     2.3. Quais parâmetros descrevem a distribuição?
#      É inteiramente descrita por seus parâmetros de média e desvio padrão, ou seja, conhecendo-se estes valores consegue-se determinar qualquer probabilidade em uma distribuição Normal

# %% [markdown]
#     2.4. Existe uma fórmula específica para calcular esperança (média) e variáncia em função dos parâmetros?
#     Média =
#    <img src="med.png">
#
#     Desvio padrão =
#
#    <img src="desv.png">
#     Variância = Desvio padrão ao quadrado

# %% [markdown]
#     2.5. Que tipo de aplicações tem esta distribuição? Em que tipo de dados é normalmente encontrada?
#
#     Podemos citar como exemplo a altura de uma determinada população que em geral segue uma distribuição normal, caracteristicas físicas e sociais,  além de uma série de  fenômenos físicos e financeiros e possuir grande uso na estatística inferencial.

# %% [markdown]
#     2.6. Essa distribuição é útil para a inferência estatística? (Os Capítulos 7 e 8 do Magalhães darão uma idéia de se sim ou não)
#
#     Sim, a distribuição gaussiana é extremamente importante para estatística inferencial.
